# %%
import torch
my_list=[[1,2,3],[4,5,6]]
print(my_list)
# Out:
# [[1, 2, 3], [4, 5, 6]]

# %%
my_tensor=torch.tensor(my_list,dtype=torch.float64)
print(my_tensor)
# Out:
# tensor([[1., 2., 3.],
#         [4., 5., 6.]], dtype=torch.float64)

# %%
# shape
print(my_tensor.shape)
# Out:
# torch.Size([2, 3])

# %%
# device
print(my_tensor.device)
# Out:
# cpu

# %%
# verification de la disponibilité du GPU
if torch.cuda.is_available():
    print("GPU is available")
else:
    print("GPU is not available")
# Out:
# GPU is not available
